# %%
import matplotlib.pyplot as plt
import seaborn
seaborn.set()
import numpy as np

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='blue')

# %%
plt.plot(x, y, '-ok', color='blue')

# %% [markdown]
# ### 散布図の作成

# %%
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
size = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=size, alpha=0.3, cmap='viridis')
plt.colorbar()

# %% [markdown]
# ### scikit-learnのirisのデータセットを見る

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2, s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel('iris features[0]')
plt.ylabel('iris features[1]')
# Out:
# Text(0, 0.5, 'iris features[1]')

# %%
features.shape
# Out:
# (4, 150)
