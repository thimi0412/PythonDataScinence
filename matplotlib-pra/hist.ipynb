# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn
seaborn.set()

# %%
data = np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  9.,  18.,  76., 168., 251., 239., 153.,  59.,  19.,   8.]),
#  array([-3.16817355, -2.53313486, -1.89809616, -1.26305746, -0.62801876,
#          0.00701994,  0.64205864,  1.27709734,  1.91213603,  2.54717473,
#          3.18221343]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, bins=30, density=True, alpha=0.5, histtype='stepfilled', color='steelblue', edgecolor='none')
# Out:
# (array([0.00472412, 0.00944824, 0.02834473, 0.03306885, 0.01889649,
#         0.03306885, 0.09920655, 0.09920655, 0.16062013, 0.19841311,
#         0.28344729, 0.31179202, 0.33068851, 0.3732056 , 0.4818604 ,
#         0.4157227 , 0.39210209, 0.32124027, 0.29761966, 0.21730959,
#         0.20786135, 0.11337892, 0.1086548 , 0.05668946, 0.06141358,
#         0.01417236, 0.01417236, 0.01889649, 0.00944824, 0.00944824]),
#  array([-3.16817355, -2.95649399, -2.74481442, -2.53313486, -2.32145529,
#         -2.10977572, -1.89809616, -1.68641659, -1.47473702, -1.26305746,
#         -1.05137789, -0.83969833, -0.62801876, -0.41633919, -0.20465963,
#          0.00701994,  0.21869951,  0.43037907,  0.64205864,  0.8537382 ,
#          1.06541777,  1.27709734,  1.4887769 ,  1.70045647,  1.91213603,
#          2.1238156 ,  2.33549517,  2.54717473,  2.7588543 ,  2.97053387,
#          3.18221343]),
#  <a list of 1 Patch objects>)

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([0.00309738, 0.        , 0.00619475, 0.00619475, 0.00929213,
#         0.03097377, 0.02168164, 0.03716852, 0.04955803, 0.04955803,
#         0.09292131, 0.10221344, 0.13008984, 0.13008984, 0.13008984,
#         0.20132951, 0.17964787, 0.17035574, 0.21371902, 0.23540066,
#         0.17345311, 0.14247934, 0.17345311, 0.13628459, 0.13938197,
#         0.13318721, 0.0805318 , 0.05885016, 0.06504492, 0.0681423 ,
#         0.03407115, 0.03407115, 0.01858426, 0.00309738, 0.01238951,
#         0.00619475, 0.00309738, 0.00309738, 0.00929213, 0.00309738]),
#  array([-3.06255392, -2.7397001 , -2.41684628, -2.09399247, -1.77113865,
#         -1.44828484, -1.12543102, -0.8025772 , -0.47972339, -0.15686957,
#          0.16598424,  0.48883806,  0.81169188,  1.13454569,  1.45739951,
#          1.78025332,  2.10310714,  2.42596096,  2.74881477,  3.07166859,
#          3.3945224 ,  3.71737622,  4.04023004,  4.36308385,  4.68593767,
#          5.00879149,  5.3316453 ,  5.65449912,  5.97735293,  6.30020675,
#          6.62306057,  6.94591438,  7.2687682 ,  7.59162201,  7.91447583,
#          8.23732965,  8.56018346,  8.88303728,  9.20589109,  9.52874491,
#          9.85159873]),
#  <a list of 1 Patch objects>)

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [ 27 244 490 212  27]

# %% [markdown]
# ### 二次元ヒストグラム

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %% [markdown]
# ### plt.hexbin 6角形のビニング

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
from scipy.stats import gaussian_kde

# %%
data = np.vstack([x, y])
kde = gaussian_kde(data)

xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

plt.imshow(Z.reshape(Xgrid.shape), origin='lower', aspect='auto', extent=[-3.5, 3.5, -6, 6], cmap='Blues')
cb = plt.colorbar()
cb.set_label('densty')
